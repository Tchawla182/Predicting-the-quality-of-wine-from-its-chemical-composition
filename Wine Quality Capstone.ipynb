# %% [markdown]
# Purpose: Collecting, Organizing, and Defining Red & White Wine Data. Provide guidance on how the physiochemical characteristics play in part to the quality of wine.
#
# What kind of cleaning steps did you perform?
#     -Data was already clean, no missing values, loading into python was a bit tricky, did it 2 different ways we can talk about it.
#
# How did you deal with missing values, if there were any? n/A
#
# Were there outliers, and how did you handle them? hard to tell which ones are outliers if any as we do not know what is useful for the dataset.

# %%
#Import pandas, matplotlib.pyplot, and seaborn in the correct lines below
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
red_wine_data = pd.read_csv('winequality-red.csv')
red_wine_data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
red_wine_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
red_wine_data.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
red_wine_data.hist(figsize = (20,15))
plt.subplots_adjust(hspace=0.5);

# %%
white_wine_data = pd.read_csv('winequality-white.csv',sep='\n', header = None)
white_wine_data = white_wine_data[0].str.split(';', expand=True)

new_header = white_wine_data.iloc[0] #Get the first row for the header
white_wine_data = wine_data[1:] #Take the data less the header row
white_wine_data.columns = new_header #Set the header row as the df header

white_wine_data.head()
# Out:
# 0 fixed acidity "volatile acidity" "citric acid" "residual sugar" "chlorides"  \
# 2           6.3                0.3          0.34              1.6       0.049
# 3           8.1               0.28           0.4              6.9        0.05
# 4           7.2               0.23          0.32              8.5       0.058
# 5           7.2               0.23          0.32              8.5       0.058
# 6           8.1               0.28           0.4              6.9        0.05
#
# 0 "free sulfur dioxide" "total sulfur dioxide" "density"  "pH" "sulphates"  \
# 2                    14                    132     0.994   3.3        0.49
# 3                    30                     97    0.9951  3.26        0.44
# 4                    47                    186    0.9956  3.19         0.4
# 5                    47                    186    0.9956  3.19         0.4
# 6                    30                     97    0.9951  3.26        0.44
#
# 0 "alcohol" "quality"
# 2       9.5         6
# ...

# %%
white_wine_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4897 entries, 2 to 4898
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   fixed acidity           4897 non-null   object
#  1   "volatile acidity"      4897 non-null   object
#  2   "citric acid"           4897 non-null   object
#  3   "residual sugar"        4897 non-null   object
#  4   "chlorides"             4897 non-null   object
#  5   "free sulfur dioxide"   4897 non-null   object
#  6   "total sulfur dioxide"  4897 non-null   object
#  7   "density"               4897 non-null   object
#  8   "pH"                    4897 non-null   object
#  9   "sulphates"             4897 non-null   object
#  10  "alcohol"               4897 non-null   object
#  11  "quality"               4897 non-null   object
# dtypes: object(12)
# memory usage: 459.2+ KB

# %%
red_wine_data.plot(x = 'quality', y = 'pH', kind = 'scatter')
# Out:
# <AxesSubplot:xlabel='quality', ylabel='pH'>

# %%
#Show a seaborn heatmap of correlations in ski_data
#Hint: call pandas' `corr()` method on `red_wine_data` and pass that into `sns.heatmap`
plt.subplots(figsize=(12,10))
sns.heatmap(red_wine_data.corr());

# %%
# define useful function to create scatterplots of ticket prices against desired columns
def scatterplots(columns, ncol=None, figsize=(15, 8)):
    if ncol is None:
        ncol = len(columns)
    nrow = int(np.ceil(len(columns) / ncol))
    fig, axes = plt.subplots(nrow, ncol, figsize=figsize, squeeze=False)
    fig.subplots_adjust(wspace=0.5, hspace=0.6)
    for i, col in enumerate(columns):
        ax = axes.flatten()[i]
        ax.scatter(x = 'quality', y = col, data= red_wine_data, alpha=0.5)
        ax.set(xlabel='quality', ylabel=col)
    nsubplots = nrow * ncol    
    for empty in range(i+1, nsubplots):
        axes.flatten()[empty].set_visible(False)
#Code task 13#
#Use a list comprehension to build a list of features from the columns of `Red_wine_data` that
#are _not_ in quality
features = [features for features in red_wine_data.columns if features not in ['quality']]
scatterplots(features, ncol=4, figsize=(15, 15))
